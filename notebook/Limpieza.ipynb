# %%
import pandas as pd

# %%
df = pd.read_excel('..\data\Indice_de_dependencia.xls')

# %%
df
# Out:
#            Índice de dependencia Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                         CC.AA.       Años        NaN        NaN        NaN
# 1                            NaN       2017       2018       2019       2020
# 2                            NaN      Total      Total      Total      Total
# 3                    España (ES)      53.83      54.19      54.29       54.2
# 4                 Andalucía (AN)      51.32      51.61       51.8      51.81
# 5                    Aragón (AR)      57.59      58.07      58.08      57.91
# 6   Asturias, Principado de (AS)      57.58      58.65      59.73      60.54
# 7            Balears, Illes (IB)      46.52      46.59      46.42      46.18
# 8                  Canarias (CN)       43.7      43.84      43.77      43.71
# 9                 Cantabria (CB)      55.05      55.95      56.56      56.96
# 10          Castilla y León (CL)      60.09      60.82      61.37      61.83
# ...

# %%
datos = df.iloc[3:, 1:]

datos
# Out:
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 3       53.83      54.19      54.29       54.2      54.04      54.16
# 4       51.32      51.61       51.8      51.81      51.71      51.66
# 5       57.59      58.07      58.08      57.91      57.62      58.59
# 6       57.58      58.65      59.73      60.54      61.07      62.07
# 7       46.52      46.59      46.42      46.18      46.29       46.6
# 8        43.7      43.84      43.77      43.71      43.84      43.96
# 9       55.05      55.95      56.56      56.96      57.17      57.62
# 10      60.09      60.82      61.37      61.83      61.82      62.52
# 11      53.81      54.12       54.2      54.04      53.46      53.53
# 12      55.46      55.69      55.51      55.23      54.82      54.77
# 13      54.31      54.71      54.86      54.75      54.72       54.6
# 14      53.96      54.29      54.56      54.71      54.67      54.88
# 15      59.55      60.37      60.94      61.34      61.64      62.08
# ...

# %%
df1 = pd.read_excel('../data/Anos_de_vida_saludable_al_nacer.xls')

df1
# Out:
#                       Años de vida saludable al nacer Unnamed: 1 Unnamed: 2  \
# 0                                              CC.AA.       Años        NaN
# 1                                                 NaN       2017        NaN
# 2                                                 NaN    Hombres    Mujeres
# 3                                         España (ES)      76.93       81.4
# 4                                      Andalucía (AN)      74.59      77.92
# 5                                         Aragón (AR)      79.15      83.78
# 6                        Asturias, Principado de (AS)      74.98       79.9
# 7                                 Balears, Illes (IB)       78.8      83.91
# 8                                       Canarias (CN)      76.12      81.26
# 9                                      Cantabria (CB)      78.83      82.21
# 10                               Castilla y León (CL)      78.26      84.46
# ...

# %%
dato = df1.iloc[3:, 1:]

dato
# Out:
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3       76.93       81.4      79.17      76.91      81.45      79.19
# 4       74.59      77.92      76.22      74.41      77.86       76.1
# 5       79.15      83.78       81.4      79.39      83.89      81.57
# 6       74.98       79.9      77.29      74.96      79.85      77.26
# 7        78.8      83.91      81.16      79.22      84.26      81.54
# 8       76.12      81.26       78.8      75.67      80.96       78.4
# 9       78.83      82.21      80.08      78.68      82.23      80.01
# 10      78.26      84.46      81.28      78.32      84.39      81.29
# 11         77      82.26      79.58      77.41      82.67      79.99
# 12      76.93      80.71      78.84      76.91      80.74      78.84
# 13      77.32      82.41       79.9       77.3      82.39      79.88
# 14         78      81.46       79.7      78.16      81.75      79.91
# 15      78.44       84.1      81.26       78.3      84.14       81.2
# ...

# %%
df1 = df1.drop(df1.tail(3).index) # BORRAR LAS TRES ULTIMAS FILAS , OLO TODOS LO TIENEN ¡¡

# %%
# def limpieza(df):
        
#     nuevas_columnas = ['CCAA'] + [str(anio) + ' ' + genero for anio, genero in zip(df.iloc[1, 1:], df.iloc[2, 1:])]  # meter número anterior ni es nan 

#     df.columns = nuevas_columnas

#     # df = df.drop([df.index[1], df.index[2]])

#     df = df.set_index('CCAA')


# df2 = limpieza(df1)

# %%
# LIMPIEZA COLUMNAS COLOCANDO AÑO Y GÉNERO:

def limpieza_columnas(df):
    
    df_copy = df.copy()
    
    years = df_copy.iloc[1].values
    genders = df_copy.iloc[2].values
    
    # Crear los nuevos nombres de las columnas
    new_columns = []
    current_year = None
    for i in range(len(years)):
        if pd.isna(years[i]):
            new_columns.append(f'{current_year}_{genders[i]}')
        else:
            current_year = years[i]
            new_columns.append(f'{current_year}_{genders[i]}')
    
    df_copy.columns = new_columns
    
    df_copy = df_copy.iloc[3:]
    
    df_copy.set_index(df_copy.columns[0], inplace=True)
    
    # Eliminar las tres últimas filas si tienen más de un 90% de valores nulos, hay algunos excel que tienen nulos al final como observaciones
    rows_to_drop = df_copy.tail(3).index[df_copy.tail(3).isnull().mean(axis=1) > 0.9]
    df_copy = df_copy.drop(rows_to_drop)
    
    
    return df_copy

test = limpieza_columnas(df1)

test
# Out:
#                              2017_Hombres 2017_Mujeres 2017_Total  \
# None_nan
# España (ES)                         76.93         81.4      79.17
# Andalucía (AN)                      74.59        77.92      76.22
# Aragón (AR)                         79.15        83.78       81.4
# Asturias, Principado de (AS)        74.98         79.9      77.29
# Balears, Illes (IB)                  78.8        83.91      81.16
# Canarias (CN)                       76.12        81.26       78.8
# Cantabria (CB)                      78.83        82.21      80.08
# Castilla y León (CL)                78.26        84.46      81.28
# Castilla - La Mancha (CM)              77        82.26      79.58
# Cataluña (CT)                       76.93        80.71      78.84
# Comunitat Valenciana (VC)           77.32        82.41       79.9
# Extremadura (EX)                       78        81.46       79.7
# Galicia (GA)                        78.44         84.1      81.26
# ...

# %%
test.iloc[0:0]
# Out:
# Empty DataFrame
# Columns: [2017_Hombres, 2017_Mujeres, 2017_Total, 2018_Hombres, 2018_Mujeres, 2018_Total, 2019_Hombres, 2019_Mujeres, 2019_Total, 2020_Hombres, 2020_Mujeres, 2020_Total, 2021_Hombres, 2021_Mujeres, 2021_Total]
# Index: []

# %%
subcolumnas = test.index.names

# Comprobamos si el dataframe tiene subcolumnas
if len(subcolumnas) > 0:
  print("El dataframe tiene subcolumnas")
else:
  print("El dataframe no tiene subcolumnas")
# Out:
# El dataframe tiene subcolumnas

# %%
subcolumnas
# Out:
# FrozenList(['None_nan'])

# %%
test.index.names
# Out:
# FrozenList(['None_nan'])

# %%
multi = test.reset_index()

# %%
columnas = [['CCAA', '2017_Hombres', '2017_Mujeres', '2017_Total',
       '2018_Hombres', '2018_Mujeres', '2018_Total', '2019_Hombres',
       '2019_Mujeres', '2019_Total', '2020_Hombres', '2020_Mujeres',
       '2020_Total', '2021_Hombres', '2021_Mujeres', '2021_Total']]

# %%
multi.columns = columnas

multi
# Out:
#                             CCAA 2017_Hombres 2017_Mujeres 2017_Total  \
# 0                    España (ES)        76.93         81.4      79.17
# 1                 Andalucía (AN)        74.59        77.92      76.22
# 2                    Aragón (AR)        79.15        83.78       81.4
# 3   Asturias, Principado de (AS)        74.98         79.9      77.29
# 4            Balears, Illes (IB)         78.8        83.91      81.16
# 5                  Canarias (CN)        76.12        81.26       78.8
# 6                 Cantabria (CB)        78.83        82.21      80.08
# 7           Castilla y León (CL)        78.26        84.46      81.28
# 8      Castilla - La Mancha (CM)           77        82.26      79.58
# 9                  Cataluña (CT)        76.93        80.71      78.84
# 10     Comunitat Valenciana (VC)        77.32        82.41       79.9
# 11              Extremadura (EX)           78        81.46       79.7
# ...
