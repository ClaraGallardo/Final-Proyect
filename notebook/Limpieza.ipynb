# %%
import pandas as pd

# %%
df1 = pd.read_excel('..\data\Ingresos_medios_por_persona_euros.xls')

df1
# Out:
#                   Ingresos medios por persona (euros) Unnamed: 1 Unnamed: 2  \
# 0                                              CC.AA.       Años        NaN
# 1                                                 NaN       2017        NaN
# 2                                                 NaN    Hombres    Mujeres
# 3                                         España (ES)      11153      10998
# 4                                      Andalucía (AN)        NaN        NaN
# 5                                         Aragón (AR)        NaN        NaN
# 6                        Asturias, Principado de (AS)        NaN        NaN
# 7                                 Balears, Illes (IB)        NaN        NaN
# 8                                       Canarias (CN)        NaN        NaN
# 9                                      Cantabria (CB)        NaN        NaN
# 10                               Castilla y León (CL)        NaN        NaN
# ...

# %%
# En este df tenemos todo nulo excepto totales y la fila España, esta me interesa
