# %%
import pandas as pd

# %%
df1 = pd.read_excel('../data/Anos_de_vida_saludable_al_nacer.xls')

df1
# Out:
#                       Años de vida saludable al nacer Unnamed: 1 Unnamed: 2  \
# 0                                              CC.AA.       Años        NaN
# 1                                                 NaN       2017        NaN
# 2                                                 NaN    Hombres    Mujeres
# 3                                         España (ES)      76.93       81.4
# 4                                      Andalucía (AN)      74.59      77.92
# 5                                         Aragón (AR)      79.15      83.78
# 6                        Asturias, Principado de (AS)      74.98       79.9
# 7                                 Balears, Illes (IB)       78.8      83.91
# 8                                       Canarias (CN)      76.12      81.26
# 9                                      Cantabria (CB)      78.83      82.21
# 10                               Castilla y León (CL)      78.26      84.46
# ...

# %%
# LIMPIEZA COLUMNAS COLOCANDO AÑO Y GÉNERO:

def limpieza_columnas(df):
    
    df_copy = df.copy()
    
    years = df_copy.iloc[1].values
    genders = df_copy.iloc[2].values
    
    # Crear los nuevos nombres de las columnas
    new_columns = []
    current_year = None
    for i in range(len(years)):
        if pd.isna(years[i]):
            new_columns.append(f'{current_year}_{genders[i]}')
        else:
            current_year = years[i]
            new_columns.append(f'{current_year}_{genders[i]}')
    
    df_copy.columns = new_columns
    
    df_copy = df_copy.iloc[3:]
    
    df_copy.set_index(df_copy.columns[0], inplace=True)
    
    # Eliminar las tres últimas filas si tienen más de un 90% de valores nulos, hay algunos excel que tienen nulos al final como observaciones
    rows_to_drop = df_copy.tail(3).index[df_copy.tail(3).isnull().mean(axis=1) > 0.9]
    df_copy = df_copy.drop(rows_to_drop)
    
    df_copy = df_copy.reset_index()
      
    df_copy.rename(columns={'None_nan': 'Region'}, inplace=True)
      
    return df_copy

test = limpieza_columnas(df1)

# %%
test
# Out:
#                           Region 2017_Hombres 2017_Mujeres 2017_Total  \
# 0                    España (ES)        76.93         81.4      79.17
# 1                 Andalucía (AN)        74.59        77.92      76.22
# 2                    Aragón (AR)        79.15        83.78       81.4
# 3   Asturias, Principado de (AS)        74.98         79.9      77.29
# 4            Balears, Illes (IB)         78.8        83.91      81.16
# 5                  Canarias (CN)        76.12        81.26       78.8
# 6                 Cantabria (CB)        78.83        82.21      80.08
# 7           Castilla y León (CL)        78.26        84.46      81.28
# 8      Castilla - La Mancha (CM)           77        82.26      79.58
# 9                  Cataluña (CT)        76.93        80.71      78.84
# 10     Comunitat Valenciana (VC)        77.32        82.41       79.9
# 11              Extremadura (EX)           78        81.46       79.7
# ...

# %%
import pandas as pd
region = []
def reorganizar_dataframe(df):
    # Crear un nuevo dataframe vacío
    nuevo_df = pd.DataFrame(columns=['Region', 'Año', 'Hombres', 'Mujeres', 'Total'])

    # Iterar sobre cada fila en el dataframe original
    for index, row in df.iterrows():
        # Obtener la región de la fila actual
        region = row['Region']

        # Iterar sobre cada año en la fila actual
        for año in range(2017, 2022):
            # Crear un nuevo dataframe con los datos de la fila y el año actuales
            df_temp = pd.DataFrame({
                'Region': [region],
                'Año': [año],
                'Hombres': [row[str(año) + ' Hombres']],
                'Mujeres': [row[str(año) + ' Mujeres']],
                'Total': [row[str(año) + ' Total']]
            })

            # Añadir el dataframe temporal al nuevo dataframe
            nuevo_df = pd.concat([nuevo_df, df_temp])

    # Restablecer los índices del nuevo dataframe
    nuevo_df.reset_index(drop=True, inplace=True)

    return nuevo_df

# %%
region = []
for index, row in test.iterrows():
        # Obtener la región de la fila actual
        region = row['Region']

# %%
test.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001D1D3989580>

# %%
# Función para transformar el DataFrame original
def transformar_dataframe(original_df, year):
    columns = ['Region', 'Año', 'Hombres', 'Mujeres', 'Total']
    new_df = pd.DataFrame(columns=columns)
    
    new_df['Region'] = original_df['Region']
    new_df['Año'] = year
    new_df['Hombres'] = original_df[f'{year}_Hombres']
    new_df['Mujeres'] = original_df[f'{year}_Mujeres']
    new_df['Total'] = original_df[f'{year}_Total']
    
    return new_df

# Iterar sobre los años y crear DataFrames transformados
years = ['2017', '2018', '2019', '2020', '2021']
transformed_dfs = [transformar_dataframe(test, year) for year in years]

# Concatenar los DataFrames resultantes
result_df = pd.concat(transformed_dfs, ignore_index=True)

# %%
result_df
# Out:
#                           Region   Año Hombres Mujeres  Total
# 0                    España (ES)  2017   76.93    81.4  79.17
# 1                 Andalucía (AN)  2017   74.59   77.92  76.22
# 2                    Aragón (AR)  2017   79.15   83.78   81.4
# 3   Asturias, Principado de (AS)  2017   74.98    79.9  77.29
# 4            Balears, Illes (IB)  2017    78.8   83.91  81.16
# ..                           ...   ...     ...     ...    ...
# 95     Navarra, C. Foral de (NC)  2021   78.36   83.33  80.86
# 96               País Vasco (PV)  2021   79.18    82.4  80.78
# 97                 La Rioja (RI)  2021      78   80.87   79.6
# 98                    Ceuta (CE)  2021   70.28   67.11   68.6
# 99                  Melilla (ML)  2021   70.28   67.11   68.6
#
# [100 rows x 5 columns]

# %%
def reorganizar_dataframe(df):

    nuevo_df = pd.DataFrame(columns=['Region', 'Año', 'Hombres', 'Mujeres', 'Total'])

    for index, row in df.iterrows():
        # Obtener la región de la fila actual
        region = row['Region']

        # Crear un nuevo dataframe con los datos de la fila y el año actuales
        df_temp = pd.DataFrame({
            'Region': [region],
            'Año': [2017],
            'Hombres': [row['2017_Hombres']],
            'Mujeres': [row['2017_Mujeres']],
            'Total': [row['2017_Total']]
        })

        # Añadir el dataframe temporal al nuevo dataframe
        nuevo_df = pd.concat([nuevo_df, df_temp])

    # Restablecer los índices del nuevo dataframe
    nuevo_df.reset_index(drop=True, inplace=True)

    return nuevo_df

# %%
import pandas as pd

# Función para transformar el DataFrame original
def transformar_dataframe(original_df, categoria):
    columns = ['Region', 'Año', 'Hombres', 'Mujeres', 'Total']
    new_df = pd.DataFrame(columns=columns)
    
    new_df['Region'] = original_df['Region']
    new_df['Año'] = original_df.filter(like=categoria).columns.str.extract('(\d+)')[0]
    new_df['Hombres'] = original_df[f'{new_df["Año"].iloc[0]}_{categoria}']
    new_df['Mujeres'] = original_df[f'{new_df["Año"].iloc[0]}_{categoria}']
    new_df['Total'] = original_df[f'{new_df["Año"].iloc[0]}_{categoria}']
    
    return new_df



categorias = ['Hombres', 'Mujeres', 'Total']

transformed_dfs = [transformar_dataframe(test, categoria) for categoria in categorias]

prueba = pd.concat(transformed_dfs, ignore_index=True)

prueba
# Out:
#                           Region   Año Hombres Mujeres  Total
# 0                    España (ES)  2017   76.93   76.93  76.93
# 1                 Andalucía (AN)  2018   74.59   74.59  74.59
# 2                    Aragón (AR)  2019   79.15   79.15  79.15
# 3   Asturias, Principado de (AS)  2020   74.98   74.98  74.98
# 4            Balears, Illes (IB)  2021    78.8    78.8   78.8
# 5                  Canarias (CN)   NaN   76.12   76.12  76.12
# 6                 Cantabria (CB)   NaN   78.83   78.83  78.83
# 7           Castilla y León (CL)   NaN   78.26   78.26  78.26
# 8      Castilla - La Mancha (CM)   NaN      77      77     77
# 9                  Cataluña (CT)   NaN   76.93   76.93  76.93
# 10     Comunitat Valenciana (VC)   NaN   77.32   77.32  77.32
# 11              Extremadura (EX)   NaN      78      78     78
# 12                  Galicia (GA)   NaN   78.44   78.44  78.44
# 13     Madrid, Comunidad de (MD)   NaN   78.94   78.94  78.94
# ...

# %%
def reformat_df(df):
    
    df_new = pd.DataFrame(columns=['Region', 'Año', 'Hombre', 'Mujer', 'Total'])
    
    years = set(col.split('_')[0] for col in df.columns if '_' in col)
    
    for year in years:
        if f'{year}_Hombres' in df.columns and f'{year}_Mujeres' in df.columns and f'{year}_Total' in df.columns:
            df_year = df[['Region', f'{year}_Hombres', f'{year}_Mujeres', f'{year}_Total']].copy()
            df_year.columns = ['Region', 'Hombre', 'Mujer', 'Total']
            df_year['Año'] = year
            df_new = pd.concat([df_new, df_year], ignore_index=True)
    return df_new

prueba = reformat_df(test)

prueba
# Out:
#                           Region   Año Hombre  Mujer  Total
# 0                    España (ES)  2020  76.76   80.6  78.69
# 1                 Andalucía (AN)  2020  77.12   80.5  78.82
# 2                    Aragón (AR)  2020  77.71  81.18  79.64
# 3   Asturias, Principado de (AS)  2020  76.24  79.85  78.08
# 4            Balears, Illes (IB)  2020  79.66  80.98   80.3
# ..                           ...   ...    ...    ...    ...
# 95     Navarra, C. Foral de (NC)  2021  78.36  83.33  80.86
# 96               País Vasco (PV)  2021  79.18   82.4  80.78
# 97                 La Rioja (RI)  2021     78  80.87   79.6
# 98                    Ceuta (CE)  2021  70.28  67.11   68.6
# 99                  Melilla (ML)  2021  70.28  67.11   68.6
#
# [100 rows x 5 columns]

# %%
prueba.tail(50)
# Out:
#                           Region   Año Hombre  Mujer  Total
# 50     Comunitat Valenciana (VC)  2017  77.32  82.41   79.9
# 51              Extremadura (EX)  2017     78  81.46   79.7
# 52                  Galicia (GA)  2017  78.44   84.1  81.26
# 53     Madrid, Comunidad de (MD)  2017  78.94  82.38  80.71
# 54        Murcia, Región de (MC)  2017  73.62  77.39  75.46
# 55     Navarra, C. Foral de (NC)  2017  77.76  81.77  79.81
# 56               País Vasco (PV)  2017  78.56  84.45  81.55
# 57                 La Rioja (RI)  2017  78.87  82.04  80.38
# 58                    Ceuta (CE)  2017  73.49  78.39  75.95
# 59                  Melilla (ML)  2017  73.49  78.39  75.95
# 60                   España (ES)  2018  76.91  81.45  79.19
# 61                Andalucía (AN)  2018  74.41  77.86   76.1
# 62                   Aragón (AR)  2018  79.39  83.89  81.57
# 63  Asturias, Principado de (AS)  2018  74.96  79.85  77.26
# 64           Balears, Illes (IB)  2018  79.22  84.26  81.54
# ...
