# %%
import streamlit as st
import pandas as pd
import sqlalchemy as sa

# %%
# Crear la conexión con la base de datos SQL usando SQLAlchemy
engine = sa.create_engine("mysql+pymysql://admin:1234@localhost/indisalud")
connection = engine.connect()

# Leer los datos de la tabla indicadores usando pandas
df = pd.read_sql_table("indicadores", connection)

# Cerrar la conexión con la base de datos
connection.close()

# Crear un título para la aplicación web
st.title("Indicadores de salud de España")

# Crear un selector para elegir el año de los datos
year = st.selectbox("Elige el año de los datos", df["año"].unique())

# Filtrar los datos según el año elegido
df_year = df[df["año"] == year]

# Crear una tabla para mostrar los datos filtrados
st.table(df_year)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\CIara\anaconda3\envs\clase\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\CIara\anaconda3\envs\clase\Lib\site-packages\sqlalchemy\engine\base.py:3292, in Engine.raw_connection(self)
#    3271 """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273 The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291 """
# -> 3292 return self.pool.connect()
#
# File c:\Users\CIara\anaconda3\envs\clase\Lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
# ...
