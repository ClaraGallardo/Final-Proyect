# %%
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../../src')
from scrape_transform_save import *

# %%
# MOVER XLS DE DESCARGAS A RAW DATA:

origen = 'C:/Users/CIara/Downloads'

raw = '../../data/raw/'

move_excel(origen, raw)
# Out:
# ['Anos_de_vida_saludable_al_nacer.xls', 'Anos_de_vida_saludable_a_los_65_anos.xls', 'Consumo_diario_de_frutas_yo_verduras_en_adultos.xls', 'Consumo_diario_de_frutas_yo_verduras_en_jovenes.xls', 'Consumo_intensivo_de_alcohol_al_menos_una_vez_al_mes_en_los_ultimos_12_meses_en_jovenes.xls', 'Deterioro_cognitivo_en_65_y_mas_anos.xls', 'Dificultad_para_la_movilidad_en_65_y_mas_anos.xls', 'Esperanza_de_vida_al_nacer.xls', 'Esperanza_de_vida_a_los_65_anos.xls', 'Incidencia_de_accidentes_de_trabajo.xls', 'Incidencia_de_nuevos_diagnosticos_de_VIH.xls', 'Incidencia_de_tuberculosis_por_100_000_hab.xls', 'Indice_de_calidad_de_vida_infantil_relacionada_con_la_salud.xls', 'Indice_de_dependencia.xls', 'Indice_de_dependencia_en_65_y_mas_anos.xls', 'Indice_de_dependencia_juvenil.xls', 'Ingresos_medios_por_persona_euros.xls', 'Limitacion_para_la_realizacion_de_actividades_relacionadas_con_el_hogar_en_65_y_mas_anos.xls', 'Numero_de_victimas_mortales_de_accidentes_de_trafico.xls', 'Numero_de_victimas_no_mortales_de_accidente_de_trafico.xls', 'Porcentaje_de_bebedores_de_riesgo_de_alcohol.xls', 'Porcentaje_de_consumidores_de_cannabis_en_escolares_adolescentes_de_14_a_18_anos.xls', 'Porcentaje_de_la_poblacion_que_declara_escasez_de_zonas_verdes_en_el_entorno_de_su_vivienda.xls', 'Porcentaje_de_la_poblacion_que_declara_que_el_ruido_procedente_del_exterior_de_su_vivienda_es_molesto.xls', 'Porcentaje_de_poblacion_adulta_en_riesgo_de_mala_salud_mental.xls', 'Porcentaje_de_poblacion_con_valoracion_positiva_de_su_estado_de_salud.xls', 'Porcentaje_de_poblacion_de_65_anos_y_mas_anos_con_valoracion_positiva_de_su_estado_de_salud.xls', 'Porcentaje_de_poblacion_de_clase_social_baja.xls', 'Porcentaje_de_poblacion_que_recibe_suministro_con_Cobertura_del_Sistema_Nacional_de_Aguas_de_Consumo.xls', 'Porcentaje_de_recien_nacidos_a_termino_con_bajo_peso.xls', 'Prevalencia_de_consumo_de_tabaco_en_poblacion_adulta.xls', 'Prevalencia_de_consumo_diario_de_tabaco_en_jovenes.xls', 'Prevalencia_de_obesidad_en_poblacion_de_18_y_mas_anos.xls', 'Prevalencia_de_obesidad_en_poblacion_infantil.xls', 'Prevalencia_de_sedentarismo_en_jovenes.xls', 'Prevalencia_de_sedentarismo_en_poblacion_adulta.xls', 'Prevalencia_registrada_de_cardiopatia_isquemica_en_poblacion_de_40_y_mas_anos.xls', 'Prevalencia_registrada_de_diabetes_mellitus_en_poblacion_general.xls', 'Prevalencia_registrada_de_EPOC_en_poblacion_de_40_y_mas_anos.xls', 'Prevalencia_registrada_de_hipertension_arterial_en_poblacion_general.xls', 'Prevalencia_registrada_de_sindromes_dolorosos_de_columna_vertebral_en_poblacion_general.xls', 'Prevalencia_registrada_de_trastornos_mentales_en_poblacion_general.xls', 'Proporcion_de_poblacion_de_25_a_64_anos_con_nivel_de_estudios_de_1_Etapa_de_educacion_secundaria_o_inferior.xls', 'Tasa_ajustada_de_hospitalizacion_por_asma_por_10_000_hab.xls', 'Tasa_ajustada_de_hospitalizacion_por_diabetes_mellitus_por_10_000_hab.xls', 'Tasa_ajustada_de_hospitalizacion_por_enfermedades_cerebrovasculares_por_10_000_hab.xls', 'Tasa_ajustada_de_hospitalizacion_por_enfermedad_hipertensiva_por_10_000_hab.xls', 'Tasa_ajustada_de_hospitalizacion_por_EPOC_por_10_000_hab.xls', 'Tasa_ajustada_de_hospitalizacion_por_infarto_agudo_de_miocardio_por_10_000_hab.xls', 'Tasa_ajustada_de_hospitalizacion_por_Insuficiencia_cardiaca_congestiva_por_10_000_hab.xls', 'Tasa_bruta_de_hospitalizacion_por_enfermedades_cerebrovasculares_por_10_000_hab.xls', 'Tasa_bruta_de_hospitalizacion_por_infarto_agudo_de_miocardio_por_10_000_hab.xls', 'Tasa_de_desempleo_en_menores_de_25_anos.xls', 'Tasa_de_desempleo_total.xls', 'Tasa_de_mortalidad_ajustada_por_edad_por_cancer_por_100_000_hab.xls', 'Tasa_de_mortalidad_ajustada_por_edad_por_cardiopatia_isquemica_por_100_000_hab.xls', 'Tasa_de_mortalidad_ajustada_por_edad_por_diabetes_mellitus_por_100_000_hab.xls', 'Tasa_de_mortalidad_ajustada_por_edad_por_enfermedad_cerebrovascular_por_100_000_hab.xls', 'Tasa_de_mortalidad_ajustada_por_edad_por_enfermedad_cronica_del_higado_por_100_000_hab.xls', 'T ...
# Archivo Anos_de_vida_saludable_al_nacer.xls copiado a ../../data/raw/
# Archivo Anos_de_vida_saludable_a_los_65_anos.xls copiado a ../../data/raw/
# Archivo Consumo_diario_de_frutas_yo_verduras_en_adultos.xls copiado a ../../data/raw/
# Archivo Consumo_diario_de_frutas_yo_verduras_en_jovenes.xls copiado a ../../data/raw/
# Archivo Consumo_intensivo_de_alcohol_al_menos_una_vez_al_mes_en_los_ultimos_12_meses_en_jovenes.xls copiado a ../../data/raw/
# Archivo Deterioro_cognitivo_en_65_y_mas_anos.xls copiado a ../../data/raw/
# Archivo Dificultad_para_la_movilidad_en_65_y_mas_anos.xls copiado a ../../data/raw/
# Archivo Esperanza_de_vida_al_nacer.xls copiado a ../../data/raw/
# Archivo Esperanza_de_vida_a_los_65_anos.xls copiado a ../../data/raw/
# Archivo Incidencia_de_accidentes_de_trabajo.xls copiado a ../../data/raw/
# Archivo Incidencia_de_nuevos_diagnosticos_de_VIH.xls copiado a ../../data/raw/
# Archivo Incidencia_de_tuberculosis_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Indice_de_calidad_de_vida_infantil_relacionada_con_la_salud.xls copiado a ../../data/raw/
# Archivo Indice_de_dependencia.xls copiado a ../../data/raw/
# Archivo Indice_de_dependencia_en_65_y_mas_anos.xls copiado a ../../data/raw/
# Archivo Indice_de_dependencia_juvenil.xls copiado a ../../data/raw/
# Archivo Ingresos_medios_por_persona_euros.xls copiado a ../../data/raw/
# Archivo Limitacion_para_la_realizacion_de_actividades_relacionadas_con_el_hogar_en_65_y_mas_anos.xls copiado a ../../data/raw/
# Archivo Numero_de_victimas_mortales_de_accidentes_de_trafico.xls copiado a ../../data/raw/
# Archivo Numero_de_victimas_no_mortales_de_accidente_de_trafico.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_bebedores_de_riesgo_de_alcohol.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_consumidores_de_cannabis_en_escolares_adolescentes_de_14_a_18_anos.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_la_poblacion_que_declara_escasez_de_zonas_verdes_en_el_entorno_de_su_vivienda.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_la_poblacion_que_declara_que_el_ruido_procedente_del_exterior_de_su_vivienda_es_molesto.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_poblacion_adulta_en_riesgo_de_mala_salud_mental.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_poblacion_con_valoracion_positiva_de_su_estado_de_salud.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_poblacion_de_65_anos_y_mas_anos_con_valoracion_positiva_de_su_estado_de_salud.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_poblacion_de_clase_social_baja.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_poblacion_que_recibe_suministro_con_Cobertura_del_Sistema_Nacional_de_Aguas_de_Consumo.xls copiado a ../../data/raw/
# Archivo Porcentaje_de_recien_nacidos_a_termino_con_bajo_peso.xls copiado a ../../data/raw/
# Archivo Prevalencia_de_consumo_de_tabaco_en_poblacion_adulta.xls copiado a ../../data/raw/
# Archivo Prevalencia_de_consumo_diario_de_tabaco_en_jovenes.xls copiado a ../../data/raw/
# Archivo Prevalencia_de_obesidad_en_poblacion_de_18_y_mas_anos.xls copiado a ../../data/raw/
# Archivo Prevalencia_de_obesidad_en_poblacion_infantil.xls copiado a ../../data/raw/
# Archivo Prevalencia_de_sedentarismo_en_jovenes.xls copiado a ../../data/raw/
# Archivo Prevalencia_de_sedentarismo_en_poblacion_adulta.xls copiado a ../../data/raw/
# Archivo Prevalencia_registrada_de_cardiopatia_isquemica_en_poblacion_de_40_y_mas_anos.xls copiado a ../../data/raw/
# Archivo Prevalencia_registrada_de_diabetes_mellitus_en_poblacion_general.xls copiado a ../../data/raw/
# Archivo Prevalencia_registrada_de_EPOC_en_poblacion_de_40_y_mas_anos.xls copiado a ../../data/raw/
# Archivo Prevalencia_registrada_de_hipertension_arterial_en_poblacion_general.xls copiado a ../../data/raw/
# Archivo Prevalencia_registrada_de_sindromes_dolorosos_de_columna_vertebral_en_poblacion_general.xls copiado a ../../data/raw/
# Archivo Prevalencia_registrada_de_trastornos_mentales_en_poblacion_general.xls copiado a ../../data/raw/
# Archivo Proporcion_de_poblacion_de_25_a_64_anos_con_nivel_de_estudios_de_1_Etapa_de_educacion_secundaria_o_inferior.xls copiado a ../../data/raw/
# Archivo Tasa_ajustada_de_hospitalizacion_por_asma_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_ajustada_de_hospitalizacion_por_diabetes_mellitus_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_ajustada_de_hospitalizacion_por_enfermedades_cerebrovasculares_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_ajustada_de_hospitalizacion_por_enfermedad_hipertensiva_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_ajustada_de_hospitalizacion_por_EPOC_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_ajustada_de_hospitalizacion_por_infarto_agudo_de_miocardio_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_ajustada_de_hospitalizacion_por_Insuficiencia_cardiaca_congestiva_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_bruta_de_hospitalizacion_por_enfermedades_cerebrovasculares_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_bruta_de_hospitalizacion_por_infarto_agudo_de_miocardio_por_10_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_desempleo_en_menores_de_25_anos.xls copiado a ../../data/raw/
# Archivo Tasa_de_desempleo_total.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_ajustada_por_edad_por_cancer_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_ajustada_por_edad_por_cardiopatia_isquemica_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_ajustada_por_edad_por_diabetes_mellitus_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_ajustada_por_edad_por_enfermedad_cerebrovascular_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_ajustada_por_edad_por_enfermedad_cronica_del_higado_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_ajustada_por_edad_por_enfermedad_pulmonar_obstructiva_cronica_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_ajustada_por_edad_por_neumonia_e_influenza_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_ajustada_por_edad_por_suicidio_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_infantil_por_1000_nacidos_vivos.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_prematura_por_cancer_ajustada_por_edad_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_prematura_por_cardiopatia_isquemica_ajustada_por_edad_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_prematura_por_diabetes_mellitus_ajustada_por_edad_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_prematura_por_enfermedad_vascular_cerebral_ajustada_por_edad_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_mortalidad_prematura_por_EPOC_ajustada_por_edad_por_100_000_hab.xls copiado a ../../data/raw/
# Archivo Tasa_de_natalidad_por_1000_habitantes.xls copiado a ../../data/raw/
# Archivo Tasa_de_riesgo_de_pobreza_indicador_AROPE.xls copiado a ../../data/raw/

# %%
# TRANFORMAR RAW DATA Y PASARLO A PROCESSED:

processed = '../../data/processed'

process_excel_files_test(raw,processed)

# %%
# LA TABLA DE INDICE DE CALIDAD DE VIDA SIGUE DANDO PROBLEMAS:

df = pd.read_csv('../../data/processed/Indice_de_calidad_de_vida_infantil_relacionada_con_la_salud.csv')

# %%
df
# Out:
#       id                        Region   Año Hombre  Mujer  Total
# 0    1.0                   España (ES)  2017  87.22  87.58  87.40
# 1    2.0                Andalucía (AN)  2017  89.75  90.18  89.96
# 2    3.0                   Aragón (AR)  2017  91.38  93.29  92.31
# 3    4.0  Asturias, Principado de (AS)  2017  79.26  82.13  80.74
# 4    5.0           Balears, Illes (IB)  2017  92.88   91.2  92.06
# 5    6.0                 Canarias (CN)  2017  92.77  91.96  92.39
# 6    7.0                Cantabria (CB)  2017  91.42  94.68  93.04
# 7    8.0          Castilla y León (CL)  2017  87.13  86.48  86.81
# 8    9.0     Castilla - La Mancha (CM)  2017  85.57  84.98  85.28
# 9   10.0                 Cataluña (CT)  2017  85.09  85.99  85.52
# 10  11.0     Comunitat Valenciana (VC)  2017   84.8  83.76  84.29
# 11  12.0              Extremadura (EX)  2017  89.56  89.63  89.60
# 12  13.0                  Galicia (GA)  2017  82.68  83.88  83.29
# 13  14.0     Madrid, Comunidad de (MD)  2017  87.67  88.39  88.02
# 14  15.0        Murcia, Región de (MC)  2017  87.27  86.93  87.11
# 15  16.0     Navarra, C. Foral de (NC)  2017   86.9  90.06  88.36
# 16  17.0               País Vasco (PV)  2017  85.85  87.56  86.71
# 17  18.0                 La Rioja (RI)  2017  89.71  84.23  86.93
# 18  19.0                    Ceuta (CE)  2017     --     --  84.37
# 19  20.0                  Melilla (ML)  2017     --     --  82.28
# 20   NaN                           NaN  2017    NaN    NaN    NaN
