# %%
import pandas as pd

# %%
df = pd.read_excel('data\Incidencia_de_nuevos_diagnosticos_de_VIH.xls')

# %%
df
# Out:
#              Incidencia de nuevos diagnósticos de VIH Unnamed: 1 Unnamed: 2  \
# 0                                              CC.AA.       Años        NaN
# 1                                                 NaN       2017        NaN
# 2                                                 NaN    Hombres    Mujeres
# 3                                         España (ES)      15.87       2.66
# 4                                      Andalucía (AN)       13.1       2.45
# 5                                         Aragón (AR)      11.69       5.71
# 6                        Asturias, Principado de (AS)       13.4       2.98
# 7                                 Balears, Illes (IB)      26.71       1.72
# 8                                       Canarias (CN)      26.05       2.66
# 9                                      Cantabria (CB)      12.34       1.68
# 10                               Castilla y León (CL)       6.85       1.22
# ...
